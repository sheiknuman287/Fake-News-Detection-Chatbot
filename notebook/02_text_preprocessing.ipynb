# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sheik\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
fake_df = pd.read_csv("../data/Fake.csv", encoding="latin-1", low_memory=False)
true_df = pd.read_csv("../data/True.csv", encoding="latin-1", low_memory=False)

fake_df['label'] = 0
true_df['label'] = 1

df = pd.concat([fake_df, true_df], axis=0)
df = df[['title', 'text', 'subject', 'date', 'label']]
df = df.sample(frac=1).reset_index(drop=True)

df.shape
# Out:
# (44919, 5)

# %%
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    words = text.split()
    words = [w for w in words if w not in stop_words]
    return " ".join(words)

df['clean_text'] = df['text'].apply(clean_text)

# %%
df[['text', 'clean_text']].head(2)
# Out:
#                                                 text  \
# 0  Eric Bolling tweeted out a heartfelt statement...
# 1  PARIS (Reuters) - French police arrested nine ...
#
#                                           clean_text
# 0  eric bolling tweeted heartfelt statement unexp...
# 1  paris reuters french police arrested nine peop...

# %%
df.shape
# Out:
# (44919, 6)
